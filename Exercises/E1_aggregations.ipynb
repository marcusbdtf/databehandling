# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("../Data/student-mat-missing-data.csv")
df.head()
# Out:
#    Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu     Mjob  \
# 0           0     GP   F  18.0       U     GT3       A     4     4  at_home
# 1           1     GP   F  17.0       U     GT3       T     1     1  at_home
# 2           2     GP   F  15.0       U     LE3       T     1     1  at_home
# 3           3     GP   F  15.0       U     GT3       T     4     2   health
# 4           4     GP   F  16.0       U     GT3       T     3     3    other
#
#    ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# 0  ...    4.0      3.0   4.0     1     1     3.0      6.0   5   6   6
# 1  ...    5.0      3.0   3.0     1     1     3.0      4.0   5   5   6
# 2  ...    4.0      3.0   2.0     2     3     3.0     10.0   7   8  10
# 3  ...    3.0      2.0   2.0     1     1     5.0      2.0  15  14  15
# 4  ...    4.0      3.0   2.0     1     2     5.0      4.0   6  10  10
#
# [5 rows x 34 columns]

# %%
import plotly_express as px
from data_utils import bPlotter as bp 

df.dtypes
# Out:
# Unnamed: 0      int64
# school         object
# sex            object
# age           float64
# address        object
# famsize        object
# Pstatus        object
# Medu            int64
# Fedu            int64
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime      int64
# studytime       int64
# failures        int64
# schoolsup      object
# famsup         object
# paid           object
# activities     object
# nursery        object
# higher         object
# internet       object
# romantic       object
# famrel        float64
# freetime      float64
# goout         float64
# Dalc            int64
# Walc            int64
# health        float64
# absences      float64
# G1              int64
# G2              int64
# G3              int64
# dtype: object

# %%
def baPlot(data, n, i):
    cdata = data.columns[data.isnull().any()]
    fig = px.bar(cdata, x=n, y=i)
    return fig
baPlot(df, "school", "absences")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4500/790737334.py in <module>
#       3     fig = px.bar(cdata, x=n, y=i)
#       4     return fig
# ----> 5 baPlot(df, "school", "absences")
#
# ~\AppData\Local\Temp/ipykernel_4500/790737334.py in baPlot(data, n, i)
#       1 def baPlot(data, n, i):
#       2     cdata = data.columns[data.isnull().any()]
# ----> 3     fig = px.bar(cdata, x=n, y=i)
#       4     return fig
#       5 baPlot(df, "school", "absences")
#
# ...

# %%
df[df.isnull().any(1)]
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 20           20     GP   M   NaN       U     GT3       T     4     3
# 71           71     GP   M   NaN       U     GT3       T     4     2
# 87           87     GP   F  15.0       U     GT3       T     4     2
# 99           99     GP   F  16.0       U     GT3       T     4     3
# 102         102     GP   M   NaN       U     GT3       T     4     4
# 106         106     GP   F   NaN       U     GT3       T     2     2
# 121         121     GP   M   NaN       U     GT3       T     2     2
# 130         130     GP   F  15.0       R     GT3       T     3     4
# 149         149     GP   M  15.0       U     LE3       A     2     1
# 151         151     GP   M  16.0       U     LE3       T     2     1
# 160         160     GP   M   NaN     NaN     LE3       T     2     1
# 188         188     GP   F   NaN       U     GT3       A     3     3
# 191         191     GP   F   NaN     NaN     GT3       T     1     1
# ...

# %%
import seaborn as sns
df = df.apply(pd.to_numeric, errors="ignore")
df2
sns.displot(data=df.isnull().melt(value_name="missing"), y="variable", hue="missing", multiple="fill")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4500/1777988640.py in <module>
#       3 null2
#       4
# ----> 5 sns.displot(data=null2, value_name="missing", y="variable", hue="missing", multiple="fill")
#
# ~\.virtualenvs\databehandling-08Ftq_K_\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2192 ):
#    2193
# -> 2194     p = _DistributionFacetPlotter(
#    2195         data=data,
#    2196         variables=_DistributionFacetPlotter.get_semantics(locals())
#
# ~\.virtualenvs\databehandling-08Ftq_K_\lib\site-packages\seaborn\distributions.py in __init__(self, data, variables)
#     109     ):
#     110
# ...

# %%
df2 = mis[df["age", "famrel", "freetime", "goout", "health", "absences"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.virtualenvs\databehandling-08Ftq_K_\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.virtualenvs\databehandling-08Ftq_K_\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.virtualenvs\databehandling-08Ftq_K_\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('age', 'famrel', 'freetime', 'goout', 'health', 'absences')
#
# ...
